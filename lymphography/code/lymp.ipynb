# %%
import pandas as p
import numpy as n
import matplotlib.pyplot as m

# %%
data=p.read_csv("lymphography (2).csv")

# %% [markdown]
# # EDA

# %%
data.columns=["class","lymphatics","block of affere: ","bl. of lymph. c","bl. of lymph. s","by pass","extravasates","regeneration ","early uptake in","lym.nodes dimin","lym.nodes enlar","changes in lym.","defect in node","changes in node","changes in stru","special forms","dislocation of","exclusion of no","no. of nodes in"]

# %%
data.dropna()
pass

# %%
data.head()
# Out:
#    class  lymphatics  block of affere:   bl. of lymph. c  bl. of lymph. s  \
# 0      2           3                  2                1                1
# 1      3           3                  2                2                2
# 2      3           3                  1                1                1
# 3      2           3                  1                1                1
# 4      2           2                  1                1                1
#
#    by pass  extravasates  regeneration   early uptake in  lym.nodes dimin  \
# 0        2             2              1                2                1
# 1        2             2              2                2                1
# 2        1             2              1                2                1
# 3        1             1              1                1                1
# 4        1             1              1                2                1
#
#    lym.nodes enlar  changes in lym.  defect in node  changes in node  \
# ...

# %%
data.shape
# Out:
# (147, 19)

# %%
data.isnull().sum()
# Out:
# class                0
# lymphatics           0
# block of affere:     0
# bl. of lymph. c      0
# bl. of lymph. s      0
# by pass              0
# extravasates         0
# regeneration         0
# early uptake in      0
# lym.nodes dimin      0
# lym.nodes enlar      0
# changes in lym.      0
# defect in node       0
# changes in node      0
# changes in stru      0
# special forms        0
# dislocation of       0
# exclusion of no      0
# no. of nodes in      0
# dtype: int64

# %%
data.count()
# Out:
# class                147
# lymphatics           147
# block of affere:     147
# bl. of lymph. c      147
# bl. of lymph. s      147
# by pass              147
# extravasates         147
# regeneration         147
# early uptake in      147
# lym.nodes dimin      147
# lym.nodes enlar      147
# changes in lym.      147
# defect in node       147
# changes in node      147
# changes in stru      147
# special forms        147
# dislocation of       147
# exclusion of no      147
# no. of nodes in      147
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   class              147 non-null    int64
#  1   lymphatics         147 non-null    int64
#  2   block of affere:   147 non-null    int64
#  3   bl. of lymph. c    147 non-null    int64
#  4   bl. of lymph. s    147 non-null    int64
#  5   by pass            147 non-null    int64
#  6   extravasates       147 non-null    int64
#  7   regeneration       147 non-null    int64
#  8   early uptake in    147 non-null    int64
#  9   lym.nodes dimin    147 non-null    int64
#  10  lym.nodes enlar    147 non-null    int64
#  11  changes in lym.    147 non-null    int64
#  12  defect in node     147 non-null    int64
#  13  changes in node    147 non-null    int64
#  14  changes in stru    147 non-null    int64
#  15  special forms      147 non-null    int64
# ...

# %%
import seaborn as s
import matplotlib.pyplot as m

# %%
s.countplot(data["class"])
# Out:
# C:\Users\Charan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
s.countplot(data["special forms"])
# Out:
# C:\Users\Charan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='special forms', ylabel='count'>

# %%
s.violinplot(x="special forms",y="class",hue="lymphatics",data=data)
# Out:
# <AxesSubplot:xlabel='special forms', ylabel='class'>

# %%
s.countplot(data["by pass"])
# Out:
# C:\Users\Charan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='by pass', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics as me

# %%
data.describe()
# Out:
#             class  lymphatics  block of affere:   bl. of lymph. c  \
# count  147.000000  147.000000         147.000000       147.000000
# mean     2.448980    2.734694           1.551020         1.176871
# std      0.575572    0.813638           0.499091         0.382864
# min      1.000000    1.000000           1.000000         1.000000
# 25%      2.000000    2.000000           1.000000         1.000000
# 50%      2.000000    3.000000           2.000000         1.000000
# 75%      3.000000    3.000000           2.000000         1.000000
# max      4.000000    4.000000           2.000000         2.000000
#
#        bl. of lymph. s     by pass  extravasates  regeneration   \
# count       147.000000  147.000000    147.000000     147.000000
# mean          1.047619    1.244898      1.510204       1.068027
# std           0.213687    0.431497      0.501605       0.252653
# min           1.000000    1.000000      1.000000       1.000000
# ...

# %% [markdown]
# # modeling

# %%
data.head()
# Out:
#    class  lymphatics  block of affere:   bl. of lymph. c  bl. of lymph. s  \
# 0      2           3                  2                1                1
# 1      3           3                  2                2                2
# 2      3           3                  1                1                1
# 3      2           3                  1                1                1
# 4      2           2                  1                1                1
#
#    by pass  extravasates  regeneration   early uptake in  lym.nodes dimin  \
# 0        2             2              1                2                1
# 1        2             2              2                2                1
# 2        1             2              1                2                1
# 3        1             1              1                1                1
# 4        1             1              1                2                1
#
#    lym.nodes enlar  changes in lym.  defect in node  changes in node  \
# ...

# %%
import sklearn
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

# %%
print(data.shape)
data.describe().transpose()
# Out:
# (147, 19)
#                    count      mean       std  min  25%  50%  75%  max
# class              147.0  2.448980  0.575572  1.0  2.0  2.0  3.0  4.0
# lymphatics         147.0  2.734694  0.813638  1.0  2.0  3.0  3.0  4.0
# block of affere:   147.0  1.551020  0.499091  1.0  1.0  2.0  2.0  2.0
# bl. of lymph. c    147.0  1.176871  0.382864  1.0  1.0  1.0  1.0  2.0
# bl. of lymph. s    147.0  1.047619  0.213687  1.0  1.0  1.0  1.0  2.0
# by pass            147.0  1.244898  0.431497  1.0  1.0  1.0  1.0  2.0
# extravasates       147.0  1.510204  0.501605  1.0  1.0  2.0  2.0  2.0
# regeneration       147.0  1.068027  0.252653  1.0  1.0  1.0  1.0  2.0
# early uptake in    147.0  1.700680  0.459526  1.0  1.0  2.0  2.0  2.0
# lym.nodes dimin    147.0  1.061224  0.314588  1.0  1.0  1.0  1.0  3.0
# lym.nodes enlar    147.0  2.476190  0.838568  1.0  2.0  2.0  3.0  4.0
# changes in lym.    147.0  2.401361  0.569305  1.0  2.0  2.0  3.0  3.0
# ...

# %%
target_column = ['lymphatics'] 
predictors = list(set(list(data.columns))-set(target_column))
data[predictors] = data[predictors]/data[predictors].max()
data.describe().transpose()
# Out:
#                    count      mean       std       min       25%       50%  \
# class              147.0  0.612245  0.143893  0.250000  0.500000  0.500000
# lymphatics         147.0  2.734694  0.813638  1.000000  2.000000  3.000000
# block of affere:   147.0  0.775510  0.249545  0.500000  0.500000  1.000000
# bl. of lymph. c    147.0  0.588435  0.191432  0.500000  0.500000  0.500000
# bl. of lymph. s    147.0  0.523810  0.106843  0.500000  0.500000  0.500000
# by pass            147.0  0.622449  0.215748  0.500000  0.500000  0.500000
# extravasates       147.0  0.755102  0.250802  0.500000  0.500000  1.000000
# regeneration       147.0  0.534014  0.126327  0.500000  0.500000  0.500000
# early uptake in    147.0  0.850340  0.229763  0.500000  0.500000  1.000000
# lym.nodes dimin    147.0  0.353741  0.104863  0.333333  0.333333  0.333333
# lym.nodes enlar    147.0  0.619048  0.209642  0.250000  0.500000  0.500000
# ...

# %%
x=data[predictors].values
y=data[target_column].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)
print(x_train.shape)
x_test.shape
# Out:
# (102, 18)
# (45, 18)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(8,8,8), activation='relu', solver='adam', max_iter=500)
mlp.fit(x_train,y_train)

predict_train = mlp.predict(x_train)
predict_test = mlp.predict(x_test)
# Out:
# C:\Users\Charan\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Charan\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_train,predict_train))
print(classification_report(y_train,predict_train))
# Out:
# [[ 0  0  1  0]
#  [ 0 38  6  4]
#  [ 0 12 17  4]
#  [ 0  7  2 11]]
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.67      0.79      0.72        48
#            3       0.65      0.52      0.58        33
#            4       0.58      0.55      0.56        20
#
#     accuracy                           0.65       102
#    macro avg       0.47      0.46      0.47       102
# weighted avg       0.64      0.65      0.64       102
# C:\Users\Charan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(confusion_matrix(y_test,predict_test))
print(classification_report(y_test,predict_test))
# Out:
# [[ 0  0  1  0]
#  [ 0 11  7  1]
#  [ 0  7  2  4]
#  [ 0  4  5  3]]
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.50      0.58      0.54        19
#            3       0.13      0.15      0.14        13
#            4       0.38      0.25      0.30        12
#
#     accuracy                           0.36        45
#    macro avg       0.25      0.25      0.24        45
# weighted avg       0.35      0.36      0.35        45
# C:\Users\Charan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import seaborn as s

# %%
# m.plot(x_train[0], label='train loss')
# m.plot(x_test[0], label='val loss')
# m.legend()
# m.show()
# m.savefig('LossVal_loss')

# %%
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
# from keras.optimizers import SGD
from matplotlib import pyplot

# %%
# generate regression dataset
X, y = make_regression(n_samples=1000, n_features=20, noise=0.1, random_state=1)
# standardize dataset
X = StandardScaler().fit_transform(X)
y = StandardScaler().fit_transform(y.reshape(len(y),1))[:,0]
# split into train and test
n_train = 500

# %%
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]
# define model

# %%
model = Sequential()
model.add(Dense(25, input_dim=20, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(1, activation='linear'))
# opt = SGD(lr=0.01, momentum=0.9)
model.compile(loss='mean_squared_error')
# fit model

# %%
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)
# evaluate the model
train_mse = model.evaluate(trainX, trainy, verbose=0)
test_mse = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_mse, test_mse))
# Out:
# Train: 0.002, Test: 0.015

# %%
# plot loss during training
pyplot.title('Loss / Mean Squared Error')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
